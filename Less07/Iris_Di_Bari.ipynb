# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
url = 'https://frenzy86.s3.eu-west-2.amazonaws.com/fav/iris.data'
dati = pd.read_csv(url, header=None, names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'])

# %%
dati['species'] = dati['species'].astype('category').cat.codes

# %%
X = dati.drop('species', axis=1)
y = dati['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=666,stratify=y)

# %%
modello = LogisticRegression()

# %%
modello.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = modello.predict(X_test)

# %%
accuratezza = accuracy_score(y_test, y_pred)

# %%
print('Accuratezza del modello:', accuratezza)
print('Matrice di confusione:\n', confusion_matrix(y_test, y_pred))
print('Report di classificazione:\n', classification_report(y_test, y_pred))
# Out:
# Accuratezza del modello: 0.9333333333333333
# Matrice di confusione:
#  [[10  0  0]
#  [ 0  9  1]
#  [ 0  1  9]]
# Report di classificazione:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      0.90      0.90        10
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style='whitegrid')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=dati, x='sepal_length', y='sepal_width', hue='species', palette='Set1')
plt.title('Grafico a dispersione: Lunghezza vs Larghezza del Sepalo')
plt.xlabel('Lunghezza del Sepalo')
plt.ylabel('Larghezza del Sepalo')
plt.legend(title='Specie')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=dati, x='petal_length', y='petal_width', hue='species', palette='Set1')
plt.title('Grafico a dispersione: Lunghezza vs Larghezza del Petalo')
plt.xlabel('Lunghezza del Petalo')
plt.ylabel('Larghezza del Petalo')
plt.legend(title='Specie')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=dati, x='species', y='petal_length', palette='Set1')
plt.title('Boxplot: Lunghezza del Petalo per Specie')
plt.xlabel('Specie')
plt.ylabel('Lunghezza del Petalo')
plt.show()
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_23836\220186861.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dati, x='species', y='petal_length', palette='Set1')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
print(conf_matrix)
# Out:
# [[10  0  0]
#  [ 0  9  1]
#  [ 0  1  9]]

# %%
class_report = classification_report(y_test, y_pred)

# %%
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      0.90      0.90        10
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %%
print('Confusion Matrix:')
print(conf_matrix)
print('\nClassification Report:')
print(class_report)
# Out:
# Confusion Matrix:
# [[10  0  0]
#  [ 0  9  1]
#  [ 0  1  9]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      0.90      0.90        10
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %%
sns.heatmap(conf_matrix,annot=True, cmap="coolwarm")
# Out:
# <Axes: >
