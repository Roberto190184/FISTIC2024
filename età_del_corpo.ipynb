# %%
import pandas as pd
import numpy as np

# %%
dict={"metabolismo":[1739,1539,1474],
      "peso":[90.6,75.4,65.1],
      "altezza":[178,178,176],
      "grasso_c":[26.5,18.5,12.3],
      "massa_musc":[52.4,38.6,30.9],
      "età_del_corpo":[45,34,18]
     }

# %%
dict
# Out:
# {'metabolismo': [1739, 1539, 1474],
#  'peso': [90.6, 75.4, 65.1],
#  'altezza': [178, 178, 176],
#  'grasso_c': [26.5, 18.5, 12.3],
#  'massa_musc': [52.4, 38.6, 30.9],
#  'età_del_corpo': [45, 34, 18]}

# %%
data = pd.DataFrame(dict)
print(data)
# Out:
#    metabolismo  peso  altezza  grasso_c  massa_musc  età_del_corpo
# 0         1739  90.6      178      26.5        52.4             45
# 1         1539  75.4      178      18.5        38.6             34
# 2         1474  65.1      176      12.3        30.9             18

# %% [markdown]
# EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(data,hue="età_del_corpo")

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(columns="età_del_corpo")
y = data["età_del_corpo"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,
                                               random_state=667,
                                               test_size=0.2)

# %%
X_test
# Out:
#    metabolismo  peso  altezza  grasso_c  massa_musc
# 0         1739  90.6      178      26.5        52.4

# %%
X_train
# Out:
#    metabolismo  peso  altezza  grasso_c  massa_musc
# 2         1474  65.1      176      12.3        30.9
# 1         1539  75.4      178      18.5        38.6

# %%
y_train
# Out:
# 2    18
# 1    34
# Name: età_del_corpo, dtype: int64

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [82.05038779]

# %% [markdown]
# misurare l'errore del modello

# %%
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error

# %%
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 37.05038778926286

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 1372.7312353347581

# %%
from sklearn.linear_model import ElasticNet

# %%
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# nan
# c:\Users\rober\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:1211: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
